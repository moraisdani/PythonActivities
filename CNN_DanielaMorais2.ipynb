# %%
import h5py
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras import backend as K
from keras.datasets import mnist
from keras.models import Sequential
from keras.preprocessing import image
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout, Flatten

def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 35, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/35
# 7/7 [==============================] - 14s 102ms/step - loss: 0.3413 - accuracy: 0.5837 - val_loss: 0.6594 - val_accuracy: 0.3400
# Epoch 2/35
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2776 - accuracy: 0.6411 - val_loss: 0.2893 - val_accuracy: 0.3400
# Epoch 3/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1816 - accuracy: 0.6794 - val_loss: 0.2483 - val_accuracy: 0.3800
# Epoch 4/35
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1658 - accuracy: 0.6938 - val_loss: 0.2514 - val_accuracy: 0.3400
# Epoch 5/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1474 - accuracy: 0.7464 - val_loss: 0.2021 - val_accuracy: 0.7800
# Epoch 6/35
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1298 - accuracy: 0.8182 - val_loss: 0.3053 - val_accuracy: 0.4400
# Epoch 7/35
# ...

# %%
# PRIMEIRA ALTERAÇÃO DE CÓDIGO - Todas as funções de ativação = RELU

def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'relu'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 35, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/35
# 7/7 [==============================] - 1s 59ms/step - loss: 11.9425 - accuracy: 0.5646 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 2/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.5850 - accuracy: 0.6411 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 3/35
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5012 - accuracy: 0.6364 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 4/35
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4931 - accuracy: 0.6507 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 5/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4964 - accuracy: 0.6507 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 6/35
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4913 - accuracy: 0.6459 - val_loss: 0.5000 - val_accuracy: 0.3400
# Epoch 7/35
# ...

# %% [markdown]
# Observa-se que alterando a função de ativação da última camada densa de Softmax para Relu, houve uma redução da acurácia para 69,99%, e aumento do teste Loss. O que não representa uma melhoria do código.

# %%
# SEGUNDA ALTERAÇÃO DE CÓDIGO - INCLUSÃO DE UMA CAMADA DENSA

def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
# Acrescedntando uma camada densa de 64
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
# Alterando tamanho desta camada para 32
model.add(Dense(32, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 35, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/35
# 7/7 [==============================] - 1s 64ms/step - loss: 0.3992 - accuracy: 0.3876 - val_loss: 0.2595 - val_accuracy: 0.3400
# Epoch 2/35
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2594 - accuracy: 0.4976 - val_loss: 0.2545 - val_accuracy: 0.3400
# Epoch 3/35
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2363 - accuracy: 0.5837 - val_loss: 0.2772 - val_accuracy: 0.3400
# Epoch 4/35
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2161 - accuracy: 0.5933 - val_loss: 0.2808 - val_accuracy: 0.3400
# Epoch 5/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2235 - accuracy: 0.5598 - val_loss: 0.2648 - val_accuracy: 0.3400
# Epoch 6/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2091 - accuracy: 0.5981 - val_loss: 0.3006 - val_accuracy: 0.3400
# Epoch 7/35
# ...

# %% [markdown]
# Observa-se que aumentando uma camada densa de 64, e alterando a camada posterior de 64 para 32, houve uma redução da acurácia. O que não representa um bom ajuste na prática.

# %%
# TERCEIRA ALTERAÇÃO - ALTERAÇÃO DO TAMANHO DO KERNEL_SIZE
def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (5, 5), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 35, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/35
# 7/7 [==============================] - 2s 96ms/step - loss: 0.3144 - accuracy: 0.6268 - val_loss: 0.6595 - val_accuracy: 0.3400
# Epoch 2/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3340 - accuracy: 0.6364 - val_loss: 0.5744 - val_accuracy: 0.3400
# Epoch 3/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2430 - accuracy: 0.6316 - val_loss: 0.3005 - val_accuracy: 0.3400
# Epoch 4/35
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1728 - accuracy: 0.6555 - val_loss: 0.2522 - val_accuracy: 0.3400
# Epoch 5/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1641 - accuracy: 0.6555 - val_loss: 0.2742 - val_accuracy: 0.3400
# Epoch 6/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1461 - accuracy: 0.7129 - val_loss: 0.1823 - val_accuracy: 0.8200
# Epoch 7/35
# ...

# %% [markdown]
# Já com a alteração do kernel_size, que inicialmente era de (3, 3), para (5, 5), o Test Loss subiu, e a acuracia reduziu. Demonstrando uma grande eficiência do modelo com apenas esta alteração.

# %%
# QUARTA ALTERAÇÃO DO CÓGICO - ALTERAÇÃO DO TAMANHO POOL_SIZE
def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
# Alteração do tamanho da camada MaxPooling
model.add(MaxPooling2D(pool_size = (8, 8)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 35, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/35
# 7/7 [==============================] - 1s 55ms/step - loss: 0.2505 - accuracy: 0.5742 - val_loss: 0.3072 - val_accuracy: 0.3400
# Epoch 2/35
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2390 - accuracy: 0.6029 - val_loss: 0.2662 - val_accuracy: 0.3400
# Epoch 3/35
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2249 - accuracy: 0.6364 - val_loss: 0.3346 - val_accuracy: 0.3400
# Epoch 4/35
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1996 - accuracy: 0.6603 - val_loss: 0.2634 - val_accuracy: 0.3400
# Epoch 5/35
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1863 - accuracy: 0.6507 - val_loss: 0.2573 - val_accuracy: 0.3400
# Epoch 6/35
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1739 - accuracy: 0.6507 - val_loss: 0.2373 - val_accuracy: 0.3400
# Epoch 7/35
# ...

# %% [markdown]
# Alterando o tamanho da camada MaxPooling2D inicialmente era (2, 2), para (8, 8), O Test Loss baixou e a Acuracia subiu. Representando uma melhoria significativa no desempenho do código.

# %%
# QUINTA ALTERAÇÃO DO CÓGICO - ALTERAÇÃO DO TAMANHO POOL_SIZE E AUMENTO DE EPOCHS
def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (8, 8)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 40, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/40
# 7/7 [==============================] - 1s 58ms/step - loss: 0.2567 - accuracy: 0.5933 - val_loss: 0.3213 - val_accuracy: 0.3400
# Epoch 2/40
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2106 - accuracy: 0.6699 - val_loss: 0.2799 - val_accuracy: 0.3400
# Epoch 3/40
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2214 - accuracy: 0.6077 - val_loss: 0.2969 - val_accuracy: 0.3400
# Epoch 4/40
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1978 - accuracy: 0.6555 - val_loss: 0.2737 - val_accuracy: 0.3400
# Epoch 5/40
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1757 - accuracy: 0.6555 - val_loss: 0.2899 - val_accuracy: 0.3400
# Epoch 6/40
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1684 - accuracy: 0.6746 - val_loss: 0.2573 - val_accuracy: 0.3400
# Epoch 7/40
# ...

# %% [markdown]
# Associando o aumento de epochs para 40, com o aumento do MaxPooling para (8, 8), foi obtido o melhor resultado dentre as demais alterações. Com acurácia de 89,99%.

# %%
# SEXTA ALTERAÇÃO DO CÓGICO - ALTERAÇÃO DO TAMANHO POOL_SIZE, AUMENTO EPOCHS E 
# AUMENTO DA QUANTIDADE DE CAMADAS DENSAS
def load_dataset():
    train_dataset = h5py.File('train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
print(train_x_orig.shape)

train_x_orig = train_x_orig / 255.
test_x_orig = test_x_orig / 255.

train_y = keras.utils.to_categorical(train_y, 2)[0]
test_y = keras.utils.to_categorical(test_y, 2)[0]

model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (8, 8)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax'))
model.compile(loss = 'mse', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(train_x_orig, train_y, batch_size = 32, epochs = 40, verbose = 1, validation_data = (test_x_orig, test_y))

score = model.evaluate(test_x_orig, test_y, verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (209, 64, 64, 3)
# Epoch 1/40
# 7/7 [==============================] - 1s 60ms/step - loss: 0.2493 - accuracy: 0.5837 - val_loss: 0.3453 - val_accuracy: 0.3400
# Epoch 2/40
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2309 - accuracy: 0.6268 - val_loss: 0.2896 - val_accuracy: 0.3400
# Epoch 3/40
# 7/7 [==============================] - 0s 29ms/step - loss: 0.2260 - accuracy: 0.6077 - val_loss: 0.2699 - val_accuracy: 0.3400
# Epoch 4/40
# 7/7 [==============================] - 0s 28ms/step - loss: 0.2173 - accuracy: 0.6651 - val_loss: 0.2804 - val_accuracy: 0.3400
# Epoch 5/40
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2025 - accuracy: 0.6411 - val_loss: 0.2642 - val_accuracy: 0.3400
# Epoch 6/40
# 7/7 [==============================] - 0s 27ms/step - loss: 0.1828 - accuracy: 0.6555 - val_loss: 0.2631 - val_accuracy: 0.3400
# Epoch 7/40
# ...

# %% [markdown]
# Associando as seguintes alterações: aumento do número de epochs para 40, permitindo uma maior profundidade de aprendizagem, aumentando a camada MaxPooling de (2, 2) para (8, 8), e acrescentando duas duas camadas densas com função de ativação relu, foi obtido um bom resultado de acurácia de 89,99% e test loss de 0,09.
